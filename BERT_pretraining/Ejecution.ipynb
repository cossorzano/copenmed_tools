# %%
from google.colab import drive
drive.mount('/content/gdrive')
 
# %tensorflow_version 1.x
# !pip install -U numpy==1.19.5
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ...

# %%
# !python '/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/create_pretraining_data.py' --input_file='/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/random/*.txt' --output_file=/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/tf_examples.tfrecord --vocab_file=/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/randomWalk_vocab.txt --do_lower_case=True --max_seq_length=61 --max_predictions_per_seq=9 --masked_lm_prob=0.15 --random_seed=12345 --dupe_factor=5
# Out:
# python3: can't open file '/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/create_pretraining_data.py': [Errno 2] No such file or directory

# %%
# !python '/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/run_pretraining.py' --input_file=/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/tf_examples.tfrecord --output_dir=/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/pretraining_output2.txt --do_train=True --do_eval=True --bert_config_file=/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/bert_config.json --train_batch_size=61 --max_seq_length=61 --max_predictions_per_seq=9 --num_train_steps=20 --num_warmup_steps=10 --learning_rate=2e-5

# %%
# !python '/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/extract_features.py' --input_file='/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/random/*.txt' --vocab_file=/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/randomWalk_vocab.txt --bert_config_file=/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/bert_config.json --init_checkpoint=/content/gdrive/MyDrive/colabnotebooks/Bert_COpenMed/pretraining_output/model.ckpt-0.index --layers=-1 --max_seq_length=61 --batch_size=8
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:  name = bert/encoder/layer_5/output/dense/bias:0, shape = (768,)
# I0518 03:36:31.463375 140053834110848 extract_features1.py:185]   name = bert/encoder/layer_5/output/dense/bias:0, shape = (768,)
# INFO:tensorflow:  name = bert/encoder/layer_5/output/LayerNorm/beta:0, shape = (768,)
# I0518 03:36:31.463558 140053834110848 extract_features1.py:185]   name = bert/encoder/layer_5/output/LayerNorm/beta:0, shape = (768,)
# INFO:tensorflow:  name = bert/encoder/layer_5/output/LayerNorm/gamma:0, shape = (768,)
# I0518 03:36:31.463730 140053834110848 extract_features1.py:185]   name = bert/encoder/layer_5/output/LayerNorm/gamma:0, shape = (768,)
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/self/query/kernel:0, shape = (768, 768)
# I0518 03:36:31.463901 140053834110848 extract_features1.py:185]   name = bert/encoder/layer_6/attention/self/query/kernel:0, shape = (768, 768)
# ...
